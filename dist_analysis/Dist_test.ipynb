# %%
import matplotlib.pyplot as plt
import pandas as pd
import random
import itertools
from numpy.random import choice
import random
from distance import DistanceSim, kendall_tau, rank_diff
import sys
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('test.csv')
print(df)
df.rename(columns = {'index':'candidate', '1': 'first', '2':'second', '3': 'third', 'Irv Order': 'IRV order'}, inplace = True)
Dist_sim = DistanceSim(df,kendall_tau)
Dist_sim.calc_distances(100)
# Out:
#    Unnamed: 0 index   1   2   3  Irv Order
# 0           0     A  39  36  24          1
# 1           1     H  32  22  20          3
# 2           2     D  25  23  25          4
# 3           3     B  24  26  19          2
# 4           4     C   9  18  31          8
# 5           5     E   8   4   3          6
# 6           6     G   7   7  11          7
# 7           7     F   6  14  17          5
#           a      b      c  dist
# 0     100.0  100.0  100.0   6.0
# 1     100.0  100.0   99.0   6.0
# 2     100.0   99.0   99.0   6.0
# 3     100.0  100.0   98.0   6.0
# 4     100.0   99.0   98.0   6.0
# ...     ...    ...    ...   ...
# 5146  100.0    4.0    0.0   7.0
# 5147  100.0    3.0    0.0   7.0
# 5148  100.0    2.0    0.0   7.0
# 5149  100.0    1.0    0.0   7.0
# 5150  100.0    0.0    0.0   7.0
#
# [5151 rows x 4 columns]

# %%
Dist_sim.gen_3d_plot()
# Out:
# /Users/brenda/Documents/rcv-distances/dist_analysis/distance.py:59: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   return ax.scatter3D(self.results_df['b'], self.results_df['c'], self.results_df['dist'])

# %%
Dist_sim_2 = DistanceSim(df, rank_diff)
Dist_sim.calc_distances(100)
# Out:
#           a      b      c  dist
# 0     100.0  100.0  100.0   6.0
# 1     100.0  100.0   99.0   6.0
# 2     100.0   99.0   99.0   6.0
# 3     100.0  100.0   98.0   6.0
# 4     100.0   99.0   98.0   6.0
# ...     ...    ...    ...   ...
# 5146  100.0    4.0    0.0   7.0
# 5147  100.0    3.0    0.0   7.0
# 5148  100.0    2.0    0.0   7.0
# 5149  100.0    1.0    0.0   7.0
# 5150  100.0    0.0    0.0   7.0
#
# [5151 rows x 4 columns]
